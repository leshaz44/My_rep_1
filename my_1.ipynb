# %% [markdown]
# <a href="https://colab.research.google.com/github/leshaz44/My_rep_1/blob/main/my_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Напишите функцию, которая принимает строку и возвращает True, если строка является палиндромом (игнорируя регистр и пробелы), и False в противном случае.щщщ

# %%
def is_palindrome(s):
    # Удаляем пробелы и приводим строку к нижнему регистру
    processed_s = "".join(filter(str.isalnum, s)).lower()
    # Сравниваем обработанную строку с ее перевернутой версией
    return processed_s == processed_s[::-1]
    print(is_palindrome("Madam"))
